# %%
import pandas as pd

# %%
df_Jan_2018 = pd.read_csv("JC-201801-citibike-tripdata.csv")
df_Feb_2018 = pd.read_csv("JC-201802-citibike-tripdata.csv")
df_Mar_2018 = pd.read_csv("JC-201803-citibike-tripdata.csv")
df_Apr_2018 = pd.read_csv("JC-201804-citibike-tripdata.csv")
df_May_2018 = pd.read_csv("JC-201805-citibike-tripdata.csv")
df_Jun_2018 = pd.read_csv("JC-201806-citibike-tripdata.csv")
df_Jul_2018 = pd.read_csv("JC-201807-citibike-tripdata.csv")
df_Aug_2018 = pd.read_csv("JC-201808-citibike-tripdata.csv") 
df_Sep_2018 = pd.read_csv("JC-201809-citibike-tripdata.csv")
df_Oct_2018 = pd.read_csv("JC-201810-citibike-tripdata.csv")
df_Nov_2018 = pd.read_csv("JC-201811-citibike-tripdata.csv")
df_Dec_2018 = pd.read_csv("JC-201812-citibike-tripdata.csv")

# %%
df = pd.concat([df_Jan_2018, df_Feb_2018, df_Mar_2018, df_Apr_2018, df_May_2018, df_Jun_2018, df_Jul_2018, \
           df_Aug_2018, df_Sep_2018, df_Oct_2018, df_Nov_2018, df_Dec_2018])

# %%
df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1               550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2               510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3               354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4               250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...             ...                       ...                       ...
# 20200          1081  2018-12-22 11:51:46.0600  2018-12-22 12:09:47.4730
# 20201           344  2018-12-25 21:40:09.8660  2018-12-25 21:45:54.2670
# 20202          1233  2018-12-29 12:55:45.9690  2018-12-29 13:16:19.5960
# 20203          1057  2018-12-30 15:32:09.3320  2018-12-30 15:49:46.3510
# 20204           301  2018-12-31 16:34:11.9340  2018-12-31 16:39:13.8340
#
#        start station id start station name  start station latitude  \
# ...

# %%
df.to_csv("JC_2018_Citibike", index = False)
